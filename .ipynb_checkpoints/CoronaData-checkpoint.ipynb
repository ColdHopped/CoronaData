# %% [markdown]
# # CoronaData

# %% [markdown]
# ### Analyze open data of RIVM
# Johan van Voskuilen, 16-08-2020 (first)

# %% [markdown]
# ##### Import Python modules

# %%
# %matplotlib inline

import os
from io import BytesIO
from zipfile import ZipFile
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import urllib.request

# %% [markdown]
# ##### Import data

# %% [markdown]
# ###### Import RIVM data on COVID-19 patients

# %%
dataurl = 'https://data.rivm.nl/covid-19/COVID-19_aantallen_gemeente_cumulatief.csv'
with urllib.request.urlopen(dataurl) as response:
    df = pd.read_csv(response, sep=';', parse_dates=[0], index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 78905 entries, 2020-03-13 10:00:00 to 2020-10-13 10:00:00
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Municipality_code   76325 non-null  object
#  1   Municipality_name   76325 non-null  object
#  2   Province            78905 non-null  object
#  3   Total_reported      78905 non-null  int64
#  4   Hospital_admission  78905 non-null  int64
#  5   Deceased            78905 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#        Total_reported  Hospital_admission      Deceased
# count    78905.000000        78905.000000  78905.000000
# mean       151.720854           28.972701     14.062163
# std        458.711888           53.075694     28.813269
# min          0.000000            0.000000      0.000000
# 25%         33.000000            7.000000      2.000000
# 50%         74.000000           16.000000      7.000000
# 75%        149.000000           32.000000     15.000000
# max      19163.000000          859.000000    380.000000

# %% [markdown]
# ###### Import KNMI temperature and humidity data from De Bilt

# %%
dataurl = r'https://cdn.knmi.nl/knmi/map/page/klimatologie/gegevens/daggegevens/etmgeg_260.zip'
with urllib.request.urlopen(dataurl) as response:
    zipfile = ZipFile(BytesIO(response.read()))
    with zipfile.open(zipfile.namelist()[0], 'r') as g:     
        dfKNMI = pd.read_csv(g, header=44, sep=',', index_col=0, parse_dates=True, skipinitialspace=True, skiprows=np.arange(49, 43585), usecols=['YYYYMMDD', 'TG', 'TN', 'TX', 'SQ', 'SP', 'PG', 'NG', 'UG', 'UN', 'UX'])
dfKNMI['TG'] = dfKNMI['TG']/10
dfKNMI['TN'] = dfKNMI['TN']/10
dfKNMI['TX'] = dfKNMI['TX']/10
dfKNMI['SQ'] = dfKNMI['SQ']/10
dfKNMI['PG'] = dfKNMI['PG']/10
dfKNMI = dfKNMI.rename(columns={ 'TG':'temperatuur gem. 24h [°C]', 'TN':'minimum temperatuur [°C]', 'TX':'maximum temperatuur [°C]', 'SQ':'zonneschijnduur [h]', 'SP':'percentage van potentiële zonneschijnduur', 'PG':'luchtdruk gem. 24h [hPa]', 'NG':'bewolkingsgraad gem. 24h', 'UG':'relatieve vochtigheid gem. 24h [%]', 'UN':'minimum vochtigheid [%]', 'UX':'maximum vochtigheid [%]'})
dfKNMI
# Out:
# Empty DataFrame
# Columns: [temperatuur gem. 24h [°C], minimum temperatuur [°C], maximum temperatuur [°C], zonneschijnduur [h], percentage van potentiële zonneschijnduur, luchtdruk gem. 24h [hPa], bewolkingsgraad gem. 24h, relatieve vochtigheid gem. 24h [%], maximum vochtigheid [%], minimum vochtigheid [%]]
# Index: []

# %% [markdown]
# ##### Analyze data

# %% [markdown]
# ###### Analyze cumulative per day

# %%
df['2020-03-13'].sum()
# Out:
# Province              GroningenGroningenGroningenGroningenFlevolandG...
# Total_reported                                                      804
# Hospital_admission                                                  115
# Deceased                                                              9
# dtype: object

# %%
CumulativePerDay = df.groupby(df.index.date).sum()
CumulativePerDay.index
# Out:
# Index([2020-03-13, 2020-03-14, 2020-03-15, 2020-03-16, 2020-03-17, 2020-03-18,
#        2020-03-19, 2020-03-20, 2020-03-21, 2020-03-22,
#        ...
#        2020-10-04, 2020-10-05, 2020-10-06, 2020-10-07, 2020-10-08, 2020-10-09,
#        2020-10-10, 2020-10-11, 2020-10-12, 2020-10-13],
#       dtype='object', length=215)

# %% [markdown]
# ###### Calculate differential per day and growth rate

# %%
CumulativePerDay
# Out:
#             Total_reported  Hospital_admission  Deceased
# 2020-03-13             804                 115         9
# 2020-03-14             959                 136        12
# 2020-03-15            1135                 162        19
# 2020-03-16            1413                 205        23
# 2020-03-17            1705                 314        40
# ...                    ...                 ...       ...
# 2020-10-09          161781               13199      6544
# 2020-10-10          168280               13248      6567
# 2020-10-11          174653               13301      6584
# 2020-10-12          181498               13359      6596
# 2020-10-13          188876               13470      6631
#
# [215 rows x 3 columns]

# %%
DifferencePerDay = CumulativePerDay.diff().fillna(CumulativePerDay).astype(int)
DifferencePerDay.tail(10)
# Out:
#             Total_reported  Hospital_admission  Deceased
# 2020-10-04            4003                  24         5
# 2020-10-05            4579                  59         7
# 2020-10-06            4528                  80        21
# 2020-10-07            4989                  63        36
# 2020-10-08            5822                  50        13
# 2020-10-09            5971                  66        13
# 2020-10-10            6499                  49        23
# 2020-10-11            6373                  53        17
# 2020-10-12            6845                  58        12
# 2020-10-13            7378                 111        35

# %%
GrowthRate = DifferencePerDay.diff().fillna(DifferencePerDay).astype(int)
GrowthRate.tail(10)
# Out:
#             Total_reported  Hospital_admission  Deceased
# 2020-10-04              36                  -6       -16
# 2020-10-05             576                  35         2
# 2020-10-06             -51                  21        14
# 2020-10-07             461                 -17        15
# 2020-10-08             833                 -13       -23
# 2020-10-09             149                  16         0
# 2020-10-10             528                 -17        10
# 2020-10-11            -126                   4        -6
# 2020-10-12             472                   5        -5
# 2020-10-13             533                  53        23

# %% [markdown]
# ###### Add rolling means

# %%
DifferencePerDay['Total_reported_rollingmean3days'] = DifferencePerDay['Total_reported'].rolling(3, min_periods=1).mean()
DifferencePerDay['Hospital_admission_rollingmean3days'] = DifferencePerDay['Hospital_admission'].rolling(3, min_periods=1).mean()
DifferencePerDay['Deceased_rollingmean3days'] = DifferencePerDay['Deceased'].rolling(3, min_periods=1).mean()
DifferencePerDay.tail()
# Out:
#             Total_reported  Hospital_admission  Deceased  \
# 2020-10-09            5971                  66        13
# 2020-10-10            6499                  49        23
# 2020-10-11            6373                  53        17
# 2020-10-12            6845                  58        12
# 2020-10-13            7378                 111        35
#
#             Total_reported_rollingmean3days  \
# 2020-10-09                      5594.000000
# 2020-10-10                      6097.333333
# 2020-10-11                      6281.000000
# 2020-10-12                      6572.333333
# 2020-10-13                      6865.333333
#
#             Hospital_admission_rollingmean3days  Deceased_rollingmean3days
# 2020-10-09                            59.666667                  20.666667
# 2020-10-10                            55.000000                  16.333333
# 2020-10-11                            56.000000                  17.666667
# 2020-10-12                            53.333333                  17.333333
# 2020-10-13                            74.000000                  21.333333

# %%
GrowthRateRollingMean3d = GrowthRate.rolling(3, min_periods=1).mean()
GrowthRateRollingMean3d.tail(10)
# Out:
#             Total_reported  Hospital_admission   Deceased
# 2020-10-04      250.333333           -7.666667  -2.666667
# 2020-10-05      251.333333           12.333333  -0.666667
# 2020-10-06      187.000000           16.666667   0.000000
# 2020-10-07      328.666667           13.000000  10.333333
# 2020-10-08      414.333333           -3.000000   2.000000
# 2020-10-09      481.000000           -4.666667  -2.666667
# 2020-10-10      503.333333           -4.666667  -4.333333
# 2020-10-11      183.666667            1.000000   1.333333
# 2020-10-12      291.333333           -2.666667  -0.333333
# 2020-10-13      293.000000           20.666667   4.000000

# %%
GrowthRateRollingMean1w = GrowthRate.rolling(7, min_periods=1).mean()

# %% [markdown]
# ###### Weekly rolling sum of new reported cases, hospital admissions and deceased

# %%
Weekly = pd.DataFrame(index=DifferencePerDay.index)
Weekly['New_reported_rollingsum1week'] = DifferencePerDay['Total_reported'].rolling(7, min_periods=1).sum()
Weekly['Hospital_admission_rollingsum1week'] = DifferencePerDay['Hospital_admission'].rolling(7, min_periods=1).sum()
Weekly['Deceased_rollingsum1week'] = DifferencePerDay['Deceased'].rolling(7, min_periods=1).sum()
Weekly.tail()
# Out:
#             New_reported_rollingsum1week  Hospital_admission_rollingsum1week  \
# 2020-10-09                       33859.0                               372.0
# 2020-10-10                       36391.0                               391.0
# 2020-10-11                       38761.0                               420.0
# 2020-10-12                       41027.0                               419.0
# 2020-10-13                       43877.0                               450.0
#
#             Deceased_rollingsum1week
# 2020-10-09                     116.0
# 2020-10-10                     118.0
# 2020-10-11                     130.0
# 2020-10-12                     135.0
# 2020-10-13                     149.0

# %% [markdown]
# ##### Plot results

# %% [markdown]
# Plot of cumulative numbers

# %%
ax = sns.lineplot(data = CumulativePerDay)

# %% [markdown]
# Plot of last days (cumulative)

# %%
ax = sns.lineplot(data = CumulativePerDay[-25:])

# %% [markdown]
# Plot of difference per day

# %%
ax = sns.lineplot(data=DifferencePerDay)

# %% [markdown]
# Zoom in on hospital admissions and deceased:

# %%
ax = sns.lineplot(data=DifferencePerDay.loc[:, ['Hospital_admission', 'Hospital_admission_rollingmean3days', 'Deceased', 'Deceased_rollingmean3days']])

# %% [markdown]
# Plot of last days (differential)

# %%
ax = sns.lineplot(data=DifferencePerDay[-50:])

# %% [markdown]
# Results of last days:

# %%
DifferencePerDay.tail(10)
# Out:
#             Total_reported  Hospital_admission  Deceased  \
# 2020-09-18            1974                  12         7
# 2020-09-19            1887                  33         2
# 2020-09-20            1844                  20         4
# 2020-09-21            2217                  26         2
# 2020-09-22            2245                  32        10
# 2020-09-23            2357                  32         5
# 2020-09-24            2544                  25        16
# 2020-09-25            2777                  36        16
# 2020-09-26            2713                  29        38
# 2020-09-27            2995                  37         8
#
#             Total_reported_rollingmean3days  \
# 2020-09-18                      1756.333333
# 2020-09-19                      1871.333333
# 2020-09-20                      1901.666667
# 2020-09-21                      1982.666667
# 2020-09-22                      2102.000000
# 2020-09-23                      2273.000000
# 2020-09-24                      2382.000000
# 2020-09-25                      2559.333333
# 2020-09-26                      2678.000000
# 2020-09-27                      2828.333333
#
#             Hospital_admission_rollingmean3days  Deceased_rollingmean3days
# 2020-09-18                            13.666667                   5.000000
# 2020-09-19                            19.666667                   5.000000
# 2020-09-20                            21.666667                   4.333333
# 2020-09-21                            26.333333                   2.666667
# 2020-09-22                            26.000000                   5.333333
# 2020-09-23                            30.000000                   5.666667
# 2020-09-24                            29.666667                  10.333333
# 2020-09-25                            31.000000                  12.333333
# 2020-09-26                            30.000000                  23.333333
# 2020-09-27                            34.000000                  20.666667

# %% [markdown]
# Weekly result of new reported cases:

# %%
ax = sns.lineplot(data=Weekly)

# %% [markdown]
# Weekly number of hospital admissions:

# %%
ax = sns.lineplot(data=Weekly['Hospital_admission_rollingsum1week'], color='orange')

# %% [markdown]
# Weekly number of deceased patients:

# %%
ax = sns.lineplot(data=Weekly['Deceased_rollingsum1week'], color='green')

# %% [markdown]
# ###### Growth rates:

# %% [markdown]
# Daily Total reported positive tests, including rolling means for 3 days and 1 week:

# %%
ax = sns.lineplot(data=GrowthRate['Total_reported'][-100:])
ax = sns.lineplot(data=GrowthRateRollingMean3d['Total_reported'][-100:])
ax = sns.lineplot(data=GrowthRateRollingMean1w['Total_reported'][-100:])

# %% [markdown]
# The same for Hospital Admission:

# %%
ax = sns.lineplot(data=GrowthRate['Hospital_admission'][-100:])
ax = sns.lineplot(data=GrowthRateRollingMean3d['Hospital_admission'][-100:])
ax = sns.lineplot(data=GrowthRateRollingMean1w['Hospital_admission'][-100:])

# %% [markdown]
# And Deceased:

# %%
ax = sns.lineplot(data=GrowthRate['Deceased'][-100:])
ax = sns.lineplot(data=GrowthRateRollingMean3d['Deceased'][-100:])
ax = sns.lineplot(data=GrowthRateRollingMean1w['Deceased'][-100:])

# %% [markdown]
# ###### Combine with KNMI weather data

# %%
ax = sns.lineplot(data=dfKNMI['temperatuur gem. 24h [°C]'], color='orange')
ax2 = ax.twinx()                                  
ax2 = sns.lineplot(data=DifferencePerDay.loc[:, ['Total_reported_rollingmean3days', 'Hospital_admission_rollingmean3days', 'Deceased_rollingmean3days']], color='green')

# %%
ax = sns.lineplot(data=dfKNMI['relatieve vochtigheid gem. 24h [%]'], color='orange')
ax2 = ax.twinx()                                  
ax2 = sns.lineplot(data=DifferencePerDay.loc[:, ['Total_reported_rollingmean3days', 'Hospital_admission_rollingmean3days', 'Deceased_rollingmean3days']], color='green')
